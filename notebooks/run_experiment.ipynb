# %%
import os

# Check if the notebook is running on Google Colab
def is_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False

# Clone the repository if running on Colab
if is_colab():
    print("Running on Google Colab. Cloning repository...")
    # !git clone https://github.com/giambono/divine_semantics.git
    os.chdir("/content/divine_semantics")
    # !pip install -r requirements.txt
else:
    import sys
    sys.path.append("..")
    print(f"Working directory set to: {os.getcwd()}")
    print("Not running on Google Colab.")
# Out:
# Working directory set to: /home/rfflpllcn/IdeaProjects/divine_semantics/notebooks
# Not running on Google Colab.

# %%
from divine_semantics.src.experiment import process_experiment, get_results_filename, load_embeddings, get_embeddings_filename
from divine_semantics.src.find_similarity import find_most_similar_ensemble

import config

# %%
MODEL = {"key": "fake_text",
         "model_name": "fake",
         "type": "TEXT"
         }
# MODEL = {"fake": "",
#          "types": ["TEXT"]
#          }
# WEIGHTS_CONFIG = {
#     "name": "weights_2",
#     "authors": {"durling": 0.2, "musa": 0.8}
# }
WEIGHTS_CONFIG = {
    "key": "weights_1",
    "authors": {
        "dante": 0.33,
        "durling": 0.25,
        "musa": 0.08,
        "kirkpatrick": 0.34
    }
}
process_experiment(MODEL, WEIGHTS_CONFIG)
# Out:
# Folder structure created successfully.
# embeddings already exists for fake_text, loading from /home/rfflpllcn/IdeaProjects/divine_semantics/experiments/embeddings/fake_text/embeddings.parquet

# %%
embeddings_path = get_embeddings_filename(MODEL["key"])
embeddings = load_embeddings(embeddings_path)

# %%
import numpy as np

w = {
        1: 0.0,
        5: 0.1,
        3: 0.4,
        4: 0.5
    }

df_select = embeddings[(embeddings["cantica_id"] == 1) & (embeddings["canto"] == 1) & (embeddings["start_verse"] == 1)]  #.embedding_fake_text.values
df_select["weight"] = df_select["author_id"].map(w)
df_select
# Out:
# /tmp/ipykernel_6540/725170244.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_select["weight"] = df_select["author_id"].map(w)
#       cantica_id  canto  start_verse  end_verse  \
# 0              1      1            1          3
# 4811           1      1            1          3
# 6407           1      1            1          3
# 8003           1      1            1          3
#
#                                                    text  author_id  type_id  \
# 0     Nel mezzo del cammin di nostra vita mi ritrova...          1        1
# 4811  In the middle of the journey of our life, I ca...          5        1
# 6407  At one point midway on our path in life,\nI ca...          4        1
# ...

# %%
np.dot(df_select["embedding_fake_text"], df_select["weight"])
# Out:
# array([0.68008896, 0.31160743, 0.35022069, ..., 0.29013186, 0.36554067,
#        0.37878749])

# %%
model_key = MODEL["key"]
weights_name = WEIGHTS_CONFIG["key"]
results_path = get_results_filename(model_key, weights_name)
df = load_embeddings(results_path)
df[(df["cantica_id"] == 1) & (df["canto"] == 1) & (df["start_verse"] == 1)]["weighted_embedding_fake_text"]
# Out:
# 0    [0.680088957092337, 0.31160742913999645, 0.350...
# Name: weighted_embedding_fake_text, dtype: object

# %%
from sentence_transformers import SentenceTransformer

# load embedding
model_key = MODEL["key"]
weights_name = WEIGHTS_CONFIG["key"]
results_path = get_results_filename(model_key, weights_name)
df = load_embeddings(results_path)
df = df[df["cantica_id"] == 1]

while True:
    # Ask the user for input
    input_text = input("Enter a verse or phrase (or type 'exit' to quit): ")

    # Check if the user wants to exit
    if input_text.lower() == 'exit':
        print("Exiting the loop. Goodbye!")
        break

    response = find_most_similar_ensemble(input_text, df)

    params = response.iloc[0][['cantica_id', 'canto', 'start_verse', 'end_verse']].to_dict()

    result_df = fetch_cantica_data(**params)

    print("Response:\n", result_df)
    print()
# Out:
# Enter a verse or phrase (or type 'exit' to quit):  in the middle of my life
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 19
#      16     print("Exiting the loop. Goodbye!")
#      17     break
# ---> 19 response = find_most_similar_ensemble(input_text, df)
#      21 params = response.iloc[0][['cantica_id', 'canto', 'start_verse', 'end_verse']].to_dict()
#      23 result_df = fetch_cantica_data(**params)
#
# File ~/IdeaProjects/divine_semantics/notebooks/../divine_semantics/src/find_similarity.py:29, in find_most_similar_ensemble(input_text, df, models)
#      27 # Load default models from config if none are provided
#      28 if models is None:
# ---> 29     with open("config.yaml", "r") as f:
#      30         config = yaml.safe_load(f)
#      31     models = {}
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config.yaml'

# %%
# !git commit -m "experiments"
# Out:
# [main 7116e1c] experiments
#  4 files changed, 13 insertions(+)
#  create mode 100644 experiments/embeddings/multilingual_e5/embeddings.parquet
#  create mode 100644 experiments/models/multilingual_e5/config.json
#  create mode 100644 experiments/results/multilingual_e5_weights_2/embeddings.parquet
#  create mode 100644 experiments/weights/weights_2.json

# %%
# !git push
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote set-url origin https://giambono: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@github.com/giambono/divine_semantics.git

# %%
import shutil

# Create a ZIP file of the folder
shutil.make_archive('/content/experiments', 'zip', '/content/divine_semantics/experiments')

# Download the ZIP file
from google.colab import files
files.download('/content/experiments.zip')

# %%
mean_squared_log_errormerg!git push origin main
# Out:
# To https://github.com/giambono/divine_semantics.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/giambono/divine_semantics.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
