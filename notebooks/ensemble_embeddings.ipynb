# %%
# !git clone https://github.com/giambono/divine_semantics.git
# Out:
# Cloning into 'divine_semantics'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 27 (delta 3), reused 22 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 26.13 KiB | 535.00 KiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
import os
os.chdir("/content/divine_semantics")

# %%
# !pip install -r requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
from src.utils import clean_dataframe
from src.compute import compute_ensemble_embeddings
from src.find_similarity import find_most_similar_ensemble
# Out:
# Mounted at /content/drive

# %%
# Load data
file_path = "/content/drive/My Drive/Progetti/Commedia/Traduzioni/inferno/I/inferno_1.csv"
df = pd.read_csv(file_path)
df = clean_dataframe(df)

# Define translation columns
columns_to_embed = ["singleton", "musa", "kirkpatrick", "durling"]

# Compute ensemble embeddings
df = compute_ensemble_embeddings(df, columns_to_embed)

# Save embeddings
df.to_csv("ensemble_embeddings.csv", index=False)
print("Embeddings saved successfully!")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/160k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/690 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# ...

# %%
# User input
input_text = input("Enter a verse or phrase: ")

# Retrieve most similar verses
df_top_matches = find_most_similar_ensemble(input_text, df, top_n=5)
# Out:
# Enter a verse or phrase: she got many wives
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name facebook/contriever. Creating a new one with mean pooling.

# %%
df_top_matches
# Out:
#       verse                                              dante  \
# 33  101-103  molti son li animali a cui s'ammoglia e più sa...
# 16    50-52  ed una lupa che di tutte brame sembiava carca ...
# 36  110-112  questi la caccerà per ogne villa fin che l'avr...
# 32   98-100  e ha natura sì malvagia e ria che mai non empi...
# 31    95-97  ché questa bestia per la qual tu gride non las...
#
#                                             singleton  \
# 33  many are the beasts with which she mates and t...
# 16  and a she-wolf that in her leanness seemed lad...
# 36  he shall hunt her through every town till he h...
# 32  and she has a nature so vicious and malign tha...
# 31  “for this beast the cause of your complaint le...
#
#                                                  musa  \
# 33  she mates with many creatures and will go on m...
# 16  and now a she-wolf came that in her leanness s...
# 36  and he will hunt for her through every city un...
# ...
